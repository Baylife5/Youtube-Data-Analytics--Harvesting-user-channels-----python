# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
# extract the users from the csv file
users = pd.read_csv('/users/baylife/desktop/csv files/users.csv')

# %%
#print the DataFrame
users.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1 Name (click to view profile)                 Date  \
# 0           1         NaN              Cartoon Connect  2019-01-02 18:25:23
# 1           2         NaN                Brandon Davis  2021-04-19 19:12:08
# 2           3         NaN                Brandon Davis  2021-04-19 19:12:18
# 3           4         NaN                itching fleas  2021-04-20 22:33:22
# 4           5         NaN                       Pain2k  2021-04-23 15:39:11
# 5           6         NaN             Lakeisha COLLINS  2021-04-24 21:54:45
# 6           7         NaN      SAVage GaMinG Lime 311R  2021-04-25 02:05:18
# 7           8         NaN                 Jaesyn Arana  2021-04-26 17:42:55
# 8           9         NaN                 Jaesyn Arana  2021-04-26 17:45:03
# 9          10         NaN                 Jaesyn Arana  2021-04-27 11:35:47
#
#    Likes isHearted isPinned  \
# 0    719        no       no
# 1      0        no       no
# 2      0        no       no
# ...

# %%
#list the columns in the csv file
users.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Name (click to view profile)', 'Date',
#        'Likes', 'isHearted', 'isPinned', 'Comment', 'Profile ID', 'Comment ID',
#        'Comment URL'],
#       dtype='object')

# %%
#delete the columns that are not needed
users.drop(['Unnamed: 0', 'Unnamed: 1','isHearted','isPinned'], axis = 1, inplace=True)

# %%
# rename the columns for convenience and print the renamed columns 
users.rename(columns={'Name (click to view profile)':'Name', 'Date':'date','Profile ID':'profile'}, inplace = True)
print("the list of columns:\n\n\t", users.columns,'\n\n')
print("the number of rows and columns: ", users.shape)
# Out:
# the list of columns:
#
# 	 Index(['Name', 'date', 'Likes', 'Comment', 'profile', 'Comment ID',
#        'Comment URL'],
#       dtype='object')
#
#
# the number of rows and columns:  (100, 7)

# %%
# change the view
pd.set_option("display.max_columns",9)
pd.set_option("display.max_rows",100)

# %%
# reordering of the columns
reordering= ['profile','Name','Likes','Comment','Comment ID','Comment URL','date']
users = users[reordering]

# %%
# sort the rows by the number of likes by each user
users.sort_values(by='Likes',ascending = False, inplace = True)
users.head(5)
# Out:
#                      profile             Name  Likes  \
# 0   UCFD4vTBo6a3Xg9yoISqjFyw  Cartoon Connect    719
# 8   UCkt59xBfW8u5uZcuCRFSxZA     Jaesyn Arana      1
# 69  UC0609Tj95Bh30eUBI6kUs1w    Woz The Scott      1
# 16  UCLDWf4mcDkYPzu3QTcFWstw      Swaggy  Boy      1
# 91  UCz9leJjhQvAO9ubO7Js4njw              カレブ      1
#
#                                               Comment  \
# 0   Intro Song: http://itunes.apple.com/album/id14...
# 8         6:55 I died during this roast session🤣🤣🤣🤣🤣🤣
# 69  Watching this while high will have you fucking...
# 16  I have to keep watching this because it’s to f...
# 91                        Ay somebody musty as hell 😂
#
#                     Comment ID  \
# 0   Ugylf6gQZtYHgumw2oR4AaABAg
# 8   Ugxh_IIoFSzYVmk7-IJ4AaABAg
# 69  UgzHWGzlg9vu3KP2Hqt4AaABAg
# 16  Ugyo_OAZYxqEichEECp4AaABAg
# 91  Ugy3Yc1lw0Dc3s2ujK14AaABAg
#
#                                           Comment URL                 date
# ...

# %%
# group the users by name
temp = users.groupby(by = 'Name')['Likes'].sum()

# %%
#print the number of distinct users 
print("there are", len(temp) ,"distinct users that have commented within the csv file")
# Out:
# there are 89 distinct users that have commented within the csv file

# %%
# describe the data set
temp.describe()
# Out:
# count     89.000000
# mean       8.224719
# std       76.199462
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      719.000000
# Name: Likes, dtype: float64

# %%
# link with protcal, Domain name and the path will be concatenated to profile ID 
link = 'https://www.youtube.com/channel/'
count = 0
for i in users['profile']:
    s = link + i
    if (users['profile'].iloc[count]== i):
        users['profile'].iloc[count] = s
        count+=1
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#get the link for each users channel
print(" \n\tput the following URLs into the browsers to be directed to the users channel\n\n")
for i in users['profile']:
        print(i,"\n")
# Out:
#
# 	put the following URLs into the browsers to be directed to the users channel
#
#
# https://www.youtube.com/channel/UCFD4vTBo6a3Xg9yoISqjFyw
#
# https://www.youtube.com/channel/UCkt59xBfW8u5uZcuCRFSxZA
#
# https://www.youtube.com/channel/UC0609Tj95Bh30eUBI6kUs1w
#
# https://www.youtube.com/channel/UCLDWf4mcDkYPzu3QTcFWstw
#
# https://www.youtube.com/channel/UCz9leJjhQvAO9ubO7Js4njw
#
# https://www.youtube.com/channel/UCeDVP3d1sepOc8Fq7k2BGnA
#
# https://www.youtube.com/channel/UCkt59xBfW8u5uZcuCRFSxZA
#
# https://www.youtube.com/channel/UCIoW8itZcVHrJqsROxyT-9w
#
# https://www.youtube.com/channel/UCkt59xBfW8u5uZcuCRFSxZA
#
# https://www.youtube.com/channel/UCyuU2OfhSPfd1KH0_nPoF7A
#
# https://www.youtube.com/channel/UCew11ZFm50KGiS66-M9OBYw
#
# https://www.youtube.com/channel/UCdxknkKu1XLfSCl_yadBxIQ
#
# https://www.youtube.com/channel/UCwT1wHaFdV9YtO4nlsIFliA
#
# https://www.youtube.com/channel/UCGyOJXTbW7eYEuEPJseRQpA
#
# https://www.youtube.com/channel/UCGhPygWOON9BbFp5rtJdSUA
# ...
